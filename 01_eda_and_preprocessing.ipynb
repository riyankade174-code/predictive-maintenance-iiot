# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Data Ingestion
df = pd.read_csv('../data/ai4i2020.csv')

# Verify shape and columns
print(f"Dataset Shape: {df.shape}")
df.head()

# %%
# Check data types and null values
print("--- Dataset Info ---")
print(df.info())

print("\n--- Missing Value Count ---")
print(df.isnull().sum())

print("\n--- Target Class Distribution (Machine failure) ---")
print(df['Machine failure'].value_counts(normalize=True) * 100)

# %%
import os
import pandas as pd

# Check relative path option 1
path_1 = '../data/ai4i2020.csv'
path_2 = 'data/ai4i2020.csv'

if os.path.exists(path_1):
    df = pd.read_csv(path_1)
elif os.path.exists(path_2):
    df = pd.read_csv(path_2)
else:
    # Absolute fallback relative to project folder
    df = pd.read_csv(os.path.join(os.path.dirname(os.getcwd()), 'data', 'ai4i2020.csv'))

print("Dataset Shape:", df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[1], line 11
#       7
#       8 if os.path.exists(path_1):
#       9     df = pd.read_csv(path_1)
#      10 elif os.path.exists(path_2):
# ---> 11     df = pd.read_csv(path_2)
#      12 else:
#      13     # Absolute fallback relative to project folder
#      14     df = pd.read_csv(os.path.join(os.path.dirname(os.getcwd()), 'data', 'ai4i2020.csv'))
#
# ...
